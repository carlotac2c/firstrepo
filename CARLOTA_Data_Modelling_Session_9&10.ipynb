# %% [markdown]
# <a href="https://colab.research.google.com/github/carlotac2c/firstrepo/blob/master/CARLOTA_Data_Modelling_Session_9%2610.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <center>Data Modeling - Session 9&10 </center>
# <img src="https://datasemantics.co/wp-content/uploads/2021/01/it-heads-guide-to-data-modelling.jpg">
#
#
#
#
# Here are the things we will do in these sessions:
#
# 1.   Pandas
# 2.   More Data Visualization
#
# <br><br>

# %% [markdown]
# #<center>PANDAS
#
# <img src=https://www.adictosaltrabajo.com/wp-content/uploads/2020/12/1200px-Pandas_logo.svg_-1068x432.png width=400>
#
# <img src="https://images.seattletimes.com/wp-content/uploads/2018/03/03292018_Pandas_150403_tzr.jpg?d=780x501">

# %% [markdown]
# ## What is Pandas?
# Pandas is a fast, powerful, flexible and easy to use open source data analysis and manipulation tool, built on top of the Python programming language.<br>
#
# ##Library Highlights
# - A fast and efficient DataFrame object for data manipulation with integrated indexing;
#
# - Tools for reading and writing data between in-memory data structures and different formats: CSV and text files, Microsoft Excel, SQL databases, and the fast HDF5 format;
#
# - Intelligent data alignment and integrated handling of missing data: gain automatic label-based alignment in computations and easily manipulate messy data into an orderly form;
#
# - Flexible reshaping and pivoting of data sets;
#
# - Intelligent label-based slicing, fancy indexing, and subsetting of large data sets;
#
# - Columns can be inserted and deleted from data structures for size mutability;
#
# - Aggregating or transforming data with a powerful group by engine allowing split-apply-combine operations on data sets;
#
# - High performance merging and joining of data sets;
#
# - Hierarchical axis indexing provides an intuitive way of working with high-dimensional data in a lower-dimensional data structure;
#
# - Time series-functionality: date range generation and frequency conversion, moving window statistics, date shifting and lagging. Even create domain-specific time offsets and join time series without losing data;
#
# - Highly optimized for performance, with critical code paths written in Cython or C.
#
# - Python with pandas is in use in a wide variety of academic and commercial domains, including Finance, Neuroscience, Economics, Statistics, Advertising, Web Analytics, and more.
#
# ##Mission
# Pandas aims to be the fundamental high-level building block for doing practical, real world data analysis in Python. Additionally, it has the broader goal of becoming the most powerful and flexible open source data analysis / manipulation tool available in any language.
#
# ##Vision
# A world where data analytics and manipulation software is:
#
# - Accessible to everyone
# - Free for users to use and modify
# - Flexible
# - Powerful
# - "Easy to use"
# - Fast

# %% [markdown]
# ## Where to learn about Pandas?
#
# <img src=https://assets.entrepreneur.com/content/3x2/2000/20181119204233-GettyImages-140892148-edit.jpeg width=400>
#
#
# [Pandas Website](https://pandas.pydata.org/)
#
# Let's go over an introduction to Pandas from the official website:<br>
# [10 Minutes to Pandas*](https://pandas.pydata.org/docs/user_guide/10min.html) <br>
# <sub> \*more like 30+ minutes </sub>

# %% [markdown]
# ## IE Students when they need to learn by themselves

# %%
from IPython.display import HTML

HTML('<img src="https://media1.tenor.com/m/xrUe4KFY0dsAAAAC/brother-ew-ew.gif" width="800">')
# Out:
# <img src="https://media1.tenor.com/m/xrUe4KFY0dsAAAAC/brother-ew-ew.gif" width="800">

# %%
from IPython.display import HTML

# Use the direct URL to the GIF
HTML('<img src="https://i.imgflip.com/7dsbg9.jpg" width="800">')
# Out:
# <img src="https://i.imgflip.com/7dsbg9.jpg" width="800">

# %%
# these are the imports
import numpy as np
import pandas as pd

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8], index=[11,2,5,4,6,7])
print(s)
print("\n\n")

print(s[4])
print(s[7])
print(s.index)
print(s.values)
print(s.values[4], s[6])
# Out:
# 11    1.0
# 2     3.0
# 5     5.0
# 4     NaN
# 6     6.0
# 7     8.0
# dtype: float64
#
#
#
# nan
# 8.0
# Index([11, 2, 5, 4, 6, 7], dtype='int64')
# [ 1.  3.  5. nan  6.  8.]
# 6.0 6.0

# %%
dates = pd.date_range("20260417", periods=100, freq="D")
print(dates)

df = pd.DataFrame(np.random.randn(100 , 4), index=dates, columns=list("ABCD"))
# df = pd.DataFrame(np.random.randint(1, 100, (6, 4)), index=dates, columns=list("ABCD"))

df

# df.index
# Out:
# DatetimeIndex(['2026-04-17', '2026-04-18', '2026-04-19', '2026-04-20',
#                '2026-04-21', '2026-04-22', '2026-04-23', '2026-04-24',
#                '2026-04-25', '2026-04-26', '2026-04-27', '2026-04-28',
#                '2026-04-29', '2026-04-30', '2026-05-01', '2026-05-02',
#                '2026-05-03', '2026-05-04', '2026-05-05', '2026-05-06',
#                '2026-05-07', '2026-05-08', '2026-05-09', '2026-05-10',
#                '2026-05-11', '2026-05-12', '2026-05-13', '2026-05-14',
#                '2026-05-15', '2026-05-16', '2026-05-17', '2026-05-18',
#                '2026-05-19', '2026-05-20', '2026-05-21', '2026-05-22',
#                '2026-05-23', '2026-05-24', '2026-05-25', '2026-05-26',
#                '2026-05-27', '2026-05-28', '2026-05-29', '2026-05-30',
#                '2026-05-31', '2026-06-01', '2026-06-02', '2026-06-03',
#                '2026-06-04', '2026-06-05', '2026-06-06', '2026-06-07',
#                '2026-06-08', '2026-06-09', '2026-06-10', '2026-06-11',
#                '2026-06-12', '2026-06-13', '2026-06-14', '2026-06-15',
#                '2026-06-16', '2026-06-17', '2026-06-18', '2026-06-19',
#                '2026-06-20', '2026-06-21', '2026-06-22', '2026-06-23',
#                '2026-06-24', '2026-06-25', '2026-06-26', '2026-06-27',
#                '2026-06-28', '2026-06-29', '2026-06-30', '2026-07-01',
#                '2026-07-02', '2026-07-03', '2026-07-04', '2026-07-05',
#                '2026-07-06', '2026-07-07', '2026-07-08', '2026-07-09',
#                '2026-07-10', '2026-07-11', '2026-07-12', '2026-07-13',
#                '2026-07-14', '2026-07-15', '2026-07-16', '2026-07-17',
#                '2026-07-18', '2026-07-19', '2026-07-20', '2026-07-21',
#                '2026-07-22', '2026-07-23', '2026-07-24', '2026-07-25'],
#               dtype='datetime64[ns]', freq='D')
#                    A         B         C         D
# 2026-04-17  1.133357  0.074440 -0.098364 -2.438221
# 2026-04-18  0.235916  0.444580 -1.029877  1.609884
# 2026-04-19 -0.512513 -0.711198  1.670803 -0.430947
# 2026-04-20 -2.821891 -0.866546  1.140542  0.132063
# 2026-04-21 -0.647502 -0.066531 -1.265027  0.376589
# ...              ...       ...       ...       ...
# 2026-07-21  0.989681 -0.488120  1.269445  0.306222
# 2026-07-22 -0.958860 -2.341592  0.677982  0.454193
# 2026-07-23 -0.756546  0.240354  0.848145  1.684142
# 2026-07-24 -1.217349  1.307855 -0.480468 -0.156404
# 2026-07-25  0.132425  1.836507  1.488686 -0.832566
#
# [100 rows x 4 columns]

# %%
df2 = pd.DataFrame(
    {
        "A": 1.0,
        "B": pd.Timestamp("20130102"),
        "C": pd.Series(1, index=list(range(4)), dtype="float32"),
        "D": np.array([3] * 4, dtype="int32"),
        "E": pd.Categorical(["test", "train", "test", "train"]),
        "F": "foo"
    }
)
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
print(df.index)
print("-----")
df.describe()
# Out:
# DatetimeIndex(['2026-04-17', '2026-04-18', '2026-04-19', '2026-04-20',
#                '2026-04-21', '2026-04-22', '2026-04-23', '2026-04-24',
#                '2026-04-25', '2026-04-26', '2026-04-27', '2026-04-28',
#                '2026-04-29', '2026-04-30', '2026-05-01', '2026-05-02',
#                '2026-05-03', '2026-05-04', '2026-05-05', '2026-05-06',
#                '2026-05-07', '2026-05-08', '2026-05-09', '2026-05-10',
#                '2026-05-11', '2026-05-12', '2026-05-13', '2026-05-14',
#                '2026-05-15', '2026-05-16', '2026-05-17', '2026-05-18',
#                '2026-05-19', '2026-05-20', '2026-05-21', '2026-05-22',
#                '2026-05-23', '2026-05-24', '2026-05-25', '2026-05-26',
#                '2026-05-27', '2026-05-28', '2026-05-29', '2026-05-30',
#                '2026-05-31', '2026-06-01', '2026-06-02', '2026-06-03',
#                '2026-06-04', '2026-06-05', '2026-06-06', '2026-06-07',
#                '2026-06-08', '2026-06-09', '2026-06-10', '2026-06-11',
#                '2026-06-12', '2026-06-13', '2026-06-14', '2026-06-15',
#                '2026-06-16', '2026-06-17', '2026-06-18', '2026-06-19',
#                '2026-06-20', '2026-06-21', '2026-06-22', '2026-06-23',
#                '2026-06-24', '2026-06-25', '2026-06-26', '2026-06-27',
#                '2026-06-28', '2026-06-29', '2026-06-30', '2026-07-01',
#                '2026-07-02', '2026-07-03', '2026-07-04', '2026-07-05',
#                '2026-07-06', '2026-07-07', '2026-07-08', '2026-07-09',
#                '2026-07-10', '2026-07-11', '2026-07-12', '2026-07-13',
#                '2026-07-14', '2026-07-15', '2026-07-16', '2026-07-17',
#                '2026-07-18', '2026-07-19', '2026-07-20', '2026-07-21',
#                '2026-07-22', '2026-07-23', '2026-07-24', '2026-07-25'],
#               dtype='datetime64[ns]', freq='D')
# -----
#                 A           B           C           D
# count  100.000000  100.000000  100.000000  100.000000
# mean     0.161995   -0.075605    0.047800    0.070377
# std      1.038117    1.125096    0.948644    0.958501
# min     -2.821891   -2.341592   -3.040035   -2.438221
# 25%     -0.538916   -0.788602   -0.573556   -0.432539
# 50%      0.169495   -0.089070   -0.063243    0.020594
# 75%      0.772341    0.593384    0.805950    0.455002
# max      2.552891    2.812092    2.339840    3.006445

# %%
print(df.T)

print(df.sort_values(by="B", ascending=True))
print(df)
# Out:
#    2026-04-17  2026-04-18  2026-04-19  2026-04-20  2026-04-21  2026-04-22  \
# A    1.133357    0.235916   -0.512513   -2.821891   -0.647502   -0.534624
# B    0.074440    0.444580   -0.711198   -0.866546   -0.066531    1.297678
# C   -0.098364   -1.029877    1.670803    1.140542   -1.265027   -0.379881
# D   -2.438221    1.609884   -0.430947    0.132063    0.376589   -0.262472
#
#    2026-04-23  2026-04-24  2026-04-25  2026-04-26  ...  2026-07-16  \
# A   -0.446825    0.567605   -0.977808   -0.831852  ...    0.227662
# B   -0.700248    0.041936   -0.208312   -1.390778  ...   -0.125415
# C    0.222536   -1.491860   -0.154657    0.236430  ...   -0.402425
# D    0.309812   -0.312654   -0.090209    0.100368  ...   -0.015399
#
#    2026-07-17  2026-07-18  2026-07-19  2026-07-20  2026-07-21  2026-07-22  \
# A    0.597204   -0.785604    2.145678    0.512551    0.989681   -0.958860
# B   -0.732292   -1.094206    0.242474    0.123464   -0.488120   -2.341592
# C    1.002920    2.339840   -0.785551   -0.325637    1.269445    0.677982
# D    0.769884   -0.073771    0.134884    0.054830    0.306222    0.454193
#
#    2026-07-23  2026-07-24  2026-07-25
# A   -0.756546   -1.217349    0.132425
# B    0.240354    1.307855    1.836507
# C    0.848145   -0.480468    1.488686
# D    1.684142   -0.156404   -0.832566
#
# [4 rows x 100 columns]
#                    A         B         C         D
# 2026-07-22 -0.958860 -2.341592  0.677982  0.454193
# 2026-05-24 -0.289790 -2.175364 -0.984022 -0.586646
# 2026-06-25  0.813744 -2.149503 -1.222987  2.229048
# 2026-07-14  0.329750 -2.028712  0.650809 -0.168502
# 2026-05-04 -0.226018 -1.904429 -0.496218  1.001142
# ...              ...       ...       ...       ...
# 2026-05-06 -0.635754  2.034339 -0.444734  0.022692
# 2026-05-03 -0.746819  2.093070 -3.040035 -0.740233
# 2026-04-28  0.312662  2.153093  1.390910  1.241104
# 2026-06-22 -0.595426  2.443574  0.850248 -0.802054
# 2026-06-02  2.171363  2.812092 -0.306258 -1.148399
#
# [100 rows x 4 columns]
#                    A         B         C         D
# 2026-04-17  1.133357  0.074440 -0.098364 -2.438221
# 2026-04-18  0.235916  0.444580 -1.029877  1.609884
# 2026-04-19 -0.512513 -0.711198  1.670803 -0.430947
# 2026-04-20 -2.821891 -0.866546  1.140542  0.132063
# 2026-04-21 -0.647502 -0.066531 -1.265027  0.376589
# ...              ...       ...       ...       ...
# 2026-07-21  0.989681 -0.488120  1.269445  0.306222
# 2026-07-22 -0.958860 -2.341592  0.677982  0.454193
# 2026-07-23 -0.756546  0.240354  0.848145  1.684142
# 2026-07-24 -1.217349  1.307855 -0.480468 -0.156404
# 2026-07-25  0.132425  1.836507  1.488686 -0.832566
#
# [100 rows x 4 columns]

# %% [markdown]
# ## Selection

# %%
print(df)
print("----")
print(df["A"]) # df.A dot notation
print("----")
print(df.B[0:3]) # Selection of a few cells of column using dot notation
print("----")
print(type(df.A))
print(df.A.values)

print(type(df.A.values))
# Out:
#                    A         B         C         D
# 2026-04-17  1.133357  0.074440 -0.098364 -2.438221
# 2026-04-18  0.235916  0.444580 -1.029877  1.609884
# 2026-04-19 -0.512513 -0.711198  1.670803 -0.430947
# 2026-04-20 -2.821891 -0.866546  1.140542  0.132063
# 2026-04-21 -0.647502 -0.066531 -1.265027  0.376589
# ...              ...       ...       ...       ...
# 2026-07-21  0.989681 -0.488120  1.269445  0.306222
# 2026-07-22 -0.958860 -2.341592  0.677982  0.454193
# 2026-07-23 -0.756546  0.240354  0.848145  1.684142
# 2026-07-24 -1.217349  1.307855 -0.480468 -0.156404
# 2026-07-25  0.132425  1.836507  1.488686 -0.832566
#
# [100 rows x 4 columns]
# ----
# 2026-04-17    1.133357
# 2026-04-18    0.235916
# 2026-04-19   -0.512513
# 2026-04-20   -2.821891
# 2026-04-21   -0.647502
#                 ...
# 2026-07-21    0.989681
# 2026-07-22   -0.958860
# 2026-07-23   -0.756546
# 2026-07-24   -1.217349
# 2026-07-25    0.132425
# Freq: D, Name: A, Length: 100, dtype: float64
# ----
# 2026-04-17    0.074440
# 2026-04-18    0.444580
# 2026-04-19   -0.711198
# Freq: D, Name: B, dtype: float64
# ----
# <class 'pandas.core.series.Series'>
# [ 1.13335688  0.23591649 -0.5125134  -2.82189097 -0.64750172 -0.53462405
#  -0.4468246   0.56760537 -0.97780768 -0.83185249 -0.3500927   0.31266162
#  -0.46185256  0.19349672 -0.38521068  0.68759954 -0.74681891 -0.22601802
#  -0.99651729 -0.63575396  0.35055333  0.47323146  0.11104153  0.42350204
#  -0.19953505 -0.80153076  1.5939111   0.73116191  1.77527059 -0.68881791
#  -0.8269245   0.69657648 -0.52986692  2.55289112 -0.68700485 -0.17176115
#   0.93854972 -0.28978998  0.96209185  1.68822847  0.05921973  0.35059853
#   0.30126804  0.37346296 -1.10732409  1.59127811  2.17136331  0.08716571
#  -0.03998373  1.31517875 -0.33111023  0.02974659  0.51589412  0.81485381
#   0.79107168  0.68535676 -2.81869446  0.53387235  1.35758557  0.85125712
#   1.46984937 -0.49405243 -0.39092163  0.50823067 -0.26654069  1.91050659
#  -0.59542646  0.50947077  1.85369844  0.81374392  1.50389123  0.1454941
#  -0.79772894 -0.91240299  1.21593776  1.6709405  -2.08118778  1.49016307
#  -0.22754006 -0.55179052  2.36088992 -1.87140083  0.37972134  0.07824349
#   0.76609769 -1.42856631  0.73832333 -0.29227955  0.32974972 -0.71165719
#   0.22766177  0.5972042  -0.78560406  2.14567812  0.51255144  0.98968052
#  -0.95886046 -0.75654627 -1.21734892  0.13242525]
# <class 'numpy.ndarray'>

# %%
print(df)
print("\n\n\n")
# slice
print(df[1:3]["A"])
# Out:
#                    A         B         C         D
# 2026-04-17  1.133357  0.074440 -0.098364 -2.438221
# 2026-04-18  0.235916  0.444580 -1.029877  1.609884
# 2026-04-19 -0.512513 -0.711198  1.670803 -0.430947
# 2026-04-20 -2.821891 -0.866546  1.140542  0.132063
# 2026-04-21 -0.647502 -0.066531 -1.265027  0.376589
# ...              ...       ...       ...       ...
# 2026-07-21  0.989681 -0.488120  1.269445  0.306222
# 2026-07-22 -0.958860 -2.341592  0.677982  0.454193
# 2026-07-23 -0.756546  0.240354  0.848145  1.684142
# 2026-07-24 -1.217349  1.307855 -0.480468 -0.156404
# 2026-07-25  0.132425  1.836507  1.488686 -0.832566
#
# [100 rows x 4 columns]
#
#
#
#
# 2026-04-18    0.235916
# 2026-04-19   -0.512513
# Freq: D, Name: A, dtype: float64

# %%
# selection with loc (by value)

dates[1] # this is the index for the second row
print(df)
print("-----")
print(dates[1])
print(df.loc["20260501"]) # selects entire row (all columns)
print(df.loc["20260501", "B"]) # select just value on column B
# Out:
#                    A         B         C         D
# 2026-04-17  1.133357  0.074440 -0.098364 -2.438221
# 2026-04-18  0.235916  0.444580 -1.029877  1.609884
# 2026-04-19 -0.512513 -0.711198  1.670803 -0.430947
# 2026-04-20 -2.821891 -0.866546  1.140542  0.132063
# 2026-04-21 -0.647502 -0.066531 -1.265027  0.376589
# ...              ...       ...       ...       ...
# 2026-07-21  0.989681 -0.488120  1.269445  0.306222
# 2026-07-22 -0.958860 -2.341592  0.677982  0.454193
# 2026-07-23 -0.756546  0.240354  0.848145  1.684142
# 2026-07-24 -1.217349  1.307855 -0.480468 -0.156404
# 2026-07-25  0.132425  1.836507  1.488686 -0.832566
#
# [100 rows x 4 columns]
# -----
# 2026-04-18 00:00:00
# A   -0.385211
# B    0.281573
# C   -1.127262
# D   -0.112480
# Name: 2026-05-01 00:00:00, dtype: float64
# 0.2815733490707691

# %%
# multiple selection with loc
print(df)
print("------")
# print(df.loc[[df.index[1],dates[4]], ["A", "C"]])
print(df.loc[["20260505", "20260502"], ["D", "C"]])
print("------")
print(df.index[1])
print("----")
# Out:
#                    A         B         C         D
# 2026-04-17  1.133357  0.074440 -0.098364 -2.438221
# 2026-04-18  0.235916  0.444580 -1.029877  1.609884
# 2026-04-19 -0.512513 -0.711198  1.670803 -0.430947
# 2026-04-20 -2.821891 -0.866546  1.140542  0.132063
# 2026-04-21 -0.647502 -0.066531 -1.265027  0.376589
# ...              ...       ...       ...       ...
# 2026-07-21  0.989681 -0.488120  1.269445  0.306222
# 2026-07-22 -0.958860 -2.341592  0.677982  0.454193
# 2026-07-23 -0.756546  0.240354  0.848145  1.684142
# 2026-07-24 -1.217349  1.307855 -0.480468 -0.156404
# 2026-07-25  0.132425  1.836507  1.488686 -0.832566
#
# [100 rows x 4 columns]
# ------
#                    D         C
# 2026-05-05 -0.762091 -1.147027
# 2026-05-02 -1.359908  0.084212
# ------
# 2026-04-18 00:00:00
# ----

# %%
df = pd.DataFrame(np.random.randn(5, 5), index=[1, 2, 3, 4, 5], columns=list("ABCDE"))
df
# Out:
#           A         B         C         D         E
# 1 -0.261449  0.695949 -0.555501  1.055876  1.291877
# 2 -0.771511  0.254289 -1.417522 -0.848787  0.849401
# 3  0.583061  0.936922  1.028441 -0.070231 -1.008300
# 4 -0.802828  1.650373 -0.186535 -0.065466 -1.485544
# 5  0.186070  1.231964  1.572655  0.480235 -0.252913

# %%
df.loc[[3,1], ["C", "D"]]
# Out:
#           C         D
# 3  1.028441 -0.070231
# 1 -0.555501  1.055876

# %% [markdown]
# ## Selection by position (iloc)

# %%
print(df)
print("----")
print(df.loc[1])
print(df.iloc[1])
print("----")
print(df.iloc[3, 3])
print("----")
print(df.iloc[1:3, 2:4])
print("----")
print(df.iloc[[0,2,4], [1,3]])
# Out:
#           A         B         C         D         E
# 1 -0.261449  0.695949 -0.555501  1.055876  1.291877
# 2 -0.771511  0.254289 -1.417522 -0.848787  0.849401
# 3  0.583061  0.936922  1.028441 -0.070231 -1.008300
# 4 -0.802828  1.650373 -0.186535 -0.065466 -1.485544
# 5  0.186070  1.231964  1.572655  0.480235 -0.252913
# ----
# A   -0.261449
# B    0.695949
# C   -0.555501
# D    1.055876
# E    1.291877
# Name: 1, dtype: float64
# A   -0.771511
# B    0.254289
# C   -1.417522
# D   -0.848787
# E    0.849401
# Name: 2, dtype: float64
# ----
# -0.06546649733070223
# ----
#           C         D
# 2 -1.417522 -0.848787
# 3  1.028441 -0.070231
# ----
#           B         D
# 1  0.695949  1.055876
# 3  0.936922 -0.070231
# 5  1.231964  0.480235

# %%
# boolean idexing
print(df)
print("---")
print(df[df.B> 0])
# Out:
#           A         B         C         D         E
# 1 -0.261449  0.695949 -0.555501  1.055876  1.291877
# 2 -0.771511  0.254289 -1.417522 -0.848787  0.849401
# 3  0.583061  0.936922  1.028441 -0.070231 -1.008300
# 4 -0.802828  1.650373 -0.186535 -0.065466 -1.485544
# 5  0.186070  1.231964  1.572655  0.480235 -0.252913
# ---
#           A         B         C         D         E
# 1 -0.261449  0.695949 -0.555501  1.055876  1.291877
# 2 -0.771511  0.254289 -1.417522 -0.848787  0.849401
# 3  0.583061  0.936922  1.028441 -0.070231 -1.008300
# 4 -0.802828  1.650373 -0.186535 -0.065466 -1.485544
# 5  0.186070  1.231964  1.572655  0.480235 -0.252913

# %% [markdown]
# Adding data

# %%
df["E"] = ["car", "toy"] * 2 + ["sheep"]
# df["James"] = 2
df["James"] = [7] * 4 + [11]

print(df)
# Out:
#           A         B         C         D      E  James
# 1 -0.261449  0.695949 -0.555501  1.055876    car      7
# 2 -0.771511  0.254289 -1.417522 -0.848787    toy      7
# 3  0.583061  0.936922  1.028441 -0.070231    car      7
# 4 -0.802828  1.650373 -0.186535 -0.065466    toy      7
# 5  0.186070  1.231964  1.572655  0.480235  sheep     11

# %%
import matplotlib.pylab as plt
print(df)

# plt.plot(df.index, df.A)

# df.plot()

# df[['A', 'C']].plot()
# print(df.iloc[:, [1, 3]])

df.iloc[:, [1,3]].plot() # same as poltting B, D columns
# Out:
#           A         B         C         D      E  James
# 1 -0.261449  0.695949 -0.555501  1.055876    car      7
# 2 -0.771511  0.254289 -1.417522 -0.848787    toy      7
# 3  0.583061  0.936922  1.028441 -0.070231    car      7
# 4 -0.802828  1.650373 -0.186535 -0.065466    toy      7
# 5  0.186070  1.231964  1.572655  0.480235  sheep     11
# <Axes: >

# %% [markdown]
# #<center> Practical Example
# Apple stock over the years and the launch of Iphones
#
# ![](https://drive.google.com/uc?id=1RGgV6RcSuNFNZ11RCRxs3ms0K9oXwJrH)

# %%
# !pip install yfinance
# Out:
# Requirement already satisfied: yfinance in /usr/local/lib/python3.12/dist-packages (0.2.66)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from yfinance) (2.2.2)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.12/dist-packages (from yfinance) (2.0.2)
# Requirement already satisfied: requests>=2.31 in /usr/local/lib/python3.12/dist-packages (from yfinance) (2.32.4)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.12/dist-packages (from yfinance) (0.0.12)
# Requirement already satisfied: platformdirs>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from yfinance) (4.9.6)
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.12/dist-packages (from yfinance) (2025.2)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.12/dist-packages (from yfinance) (2.4.7)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.12/dist-packages (from yfinance) (4.0.4)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.12/dist-packages (from yfinance) (4.13.5)
# Requirement already satisfied: curl_cffi>=0.7 in /usr/local/lib/python3.12/dist-packages (from yfinance) (0.15.0)
# Requirement already satisfied: protobuf>=3.19.0 in /usr/local/lib/python3.12/dist-packages (from yfinance) (5.29.6)
# Requirement already satisfied: websockets>=13.0 in /usr/local/lib/python3.12/dist-packages (from yfinance) (15.0.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (4.15.0)
# Requirement already satisfied: cffi>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from curl_cffi>=0.7->yfinance) (2.0.0)
# Requirement already satisfied: certifi>=2024.2.2 in /usr/local/lib/python3.12/dist-packages (from curl_cffi>=0.7->yfinance) (2026.2.25)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from curl_cffi>=0.7->yfinance) (13.9.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.3.0->yfinance) (2026.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31->yfinance) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31->yfinance) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31->yfinance) (2.5.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=2.0.0->curl_cffi>=0.7->yfinance) (3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->curl_cffi>=0.7->yfinance) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->curl_cffi>=0.7->yfinance) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->curl_cffi>=0.7->yfinance) (0.1.2)

# %%
import requests

r = requests.get("https://github.com/itb-ie/pandas-apple-stock/raw/master/iphone-dates.xlsx")
with open("sample_data/launch.xlsx", "wb") as f:
  f.write(r.content)

# %%
# !wget https://github.com/itb-ie/pandas-apple-stock/raw/master/iphone-dates.xlsx -O sample_data/launch2.xlsx
# Out:
# --2026-04-17 09:38:34--  https://github.com/itb-ie/pandas-apple-stock/raw/master/iphone-dates.xlsx
# Resolving github.com (github.com)... 140.82.114.3
# Connecting to github.com (github.com)|140.82.114.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/itb-ie/pandas-apple-stock/master/iphone-dates.xlsx [following]
# --2026-04-17 09:38:34--  https://raw.githubusercontent.com/itb-ie/pandas-apple-stock/master/iphone-dates.xlsx
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10347 (10K) [application/octet-stream]
# Saving to: ‘sample_data/launch2.xlsx’
#
# sample_data/launch2 100%[===================>]  10.10K  --.-KB/s    in 0s
#
# 2026-04-17 09:38:34 (99.1 MB/s) - ‘sample_data/launch2.xlsx’ saved [10347/10347]

# %%
import matplotlib.pyplot as plt
import pandas as pd
import yfinance as yf

# Fetch AAPL data
df_stock = yf.download('AAPL', start='2007-01-01', end='2026-04-15')

df_launch = pd.read_excel("sample_data/launch.xlsx")

df_launch['Date'] = pd.to_datetime(df_launch.date)
df_stock['Date'] = pd.to_datetime(df_stock.index)
df_stock.insert(0, 'ID', range(0, len(df_stock)))
print(df_stock)
print(df_launch)

# Initialize list to store matched IDs
matched_ids = []

# Loop through each launch date
for launch_date in df_launch['Date']:
    # Try matching exact date, +1 day, or +2 days
    for offset in [0, 1, 2]:
        check_date = launch_date + pd.Timedelta(days=offset)
        matching_row = df_stock[df_stock['Date'] == check_date]

        # If a match is found, store the ID and stop checking offsets
        if not matching_row.empty:
            matched_ids.append(int(matching_row['ID'].iloc[0]))
            break
    else:
        # If no match is found after checking all offsets, print a message
        print(f"No trading day found for {launch_date} within 2 days")

print(matched_ids)

plt.figure("Apple Stock")
plt.figure(figsize = (20, 10))
plt.plot(df_stock["Date"], df_stock["Close"], '-v', ms=11, mfc="red", linewidth=0.6,
         markevery=matched_ids, label="Iphone launch date")
plt.xlabel("Dates")
plt.legend(loc="upper left")
plt.show()
df_stock.to_csv("sample_data/result.csv")
# Out:
# /tmp/ipykernel_9796/2971897810.py:6: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df_stock = yf.download('AAPL', start='2007-01-01', end='2026-04-15')
# [*********************100%***********************]  1 of 1 completed
# Price         ID       Close        High         Low        Open      Volume  \
# Ticker                  AAPL        AAPL        AAPL        AAPL        AAPL
# Date
# 2007-01-03     0    2.510900    2.594198    2.453971    2.585508  1238319600
# 2007-01-04     1    2.566632    2.575321    2.511499    2.518391   847260400
# 2007-01-05     2    2.548353    2.582811    2.528878    2.569927   834741600
# 2007-01-08     3    2.560938    2.592699    2.555245    2.575620   797106800
# 2007-01-09     4    2.773675    2.785960    2.551350    2.590302  3349298400
# ...          ...         ...         ...         ...         ...         ...
# 2026-04-08  4845  258.899994  259.750000  256.529999  258.450012    41032800
# 2026-04-09  4846  260.489990  261.119995  256.070007  259.000000    28121600
# 2026-04-10  4847  260.480011  262.190002  259.019989  259.980011    31291500
# 2026-04-13  4848  259.200012  260.179993  256.660004  259.730011    36234700
# 2026-04-14  4849  258.829987  261.929993  257.190002  259.250000    48370700
#
# Price            Date
# Ticker
# Date
# 2007-01-03 2007-01-03
# 2007-01-04 2007-01-04
# 2007-01-05 2007-01-05
# 2007-01-08 2007-01-08
# 2007-01-09 2007-01-09
# ...               ...
# 2026-04-08 2026-04-08
# 2026-04-09 2026-04-09
# 2026-04-10 2026-04-10
# 2026-04-13 2026-04-13
# 2026-04-14 2026-04-14
#
# [4850 rows x 7 columns]
#                             model       date       Date
# 0                          iPhone 2007-06-29 2007-06-29
# 1                       iPhone 3G 2008-07-11 2008-07-11
# 2                      iPhone 3GS 2009-06-19 2009-06-19
# 3                        iPhone 4 2010-06-24 2010-06-24
# 4                       iPhone 4s 2011-10-14 2011-10-14
# 5                        iPhone 5 2012-09-21 2012-09-21
# 6                   iPhone 5C, 5s 2013-09-20 2013-09-20
# 7                iPhone 6, 6 Plus 2014-09-19 2014-09-19
# 8              iPhone 6s, 6s Plus 2015-09-25 2015-09-25
# 9                       iPhone SE 2016-03-31 2016-03-31
# 10               iPhone 7, 7 Plus 2016-09-16 2016-09-16
# 11               iPhone 8, 8 Plus 2017-09-22 2017-09-22
# 12                       iPhone X 2017-11-03 2017-11-03
# 13              iPhone XS, XS Max 2018-09-21 2018-09-21
# 14                      iPhone XR 2018-10-26 2018-10-26
# 15  iPhone 11, 11 Pro, 11 Pro Max 2019-09-20 2019-09-20
# 16                      Iphone 12 2020-10-23 2020-10-23
# 17                      Iphone 13 2021-09-24 2021-09-24
# 18                      Iphone 14 2022-09-16 2022-09-16
# 19                      Iphone 15 2023-09-22 2023-09-22
# 20                      Iphone 16 2024-09-20 2024-09-20
# 21                     Iphone 16e 2025-02-28 2025-02-28
# 22                      Iphone 17 2025-09-19 2025-09-19
# [123, 383, 620, 875, 1206, 1442, 1691, 1942, 2198, 2326, 2444, 2700, 2730, 2951, 2976, 3201, 3477, 3708, 3954, 4209, 4459, 4568, 4708]

# %%
# Plotting using pandas' built-in functionality
ax = df_stock['Close'].plot(
    figsize=(20, 10),
    style='-ob',
    linewidth=0.2,
    markevery=matched_ids,  # Highlight the launch dates
    markerfacecolor='green',
    markersize=10,
    label='Close Price'
)

# Highlight iPhone launch dates with vertical lines
for launch_date in df_stock.iloc[matched_ids].index:
    ax.axvline(x=launch_date, color='gray', linestyle='--', linewidth=1.5)

# Labeling and legend
ax.set_xlabel("Date")
ax.set_ylabel("Close Price")
ax.set_title("Apple Stock Prices with iPhone Launch Dates Highlighted")
ax.legend(loc="upper left")

# Show the plot
plt.show()

# %%
from matplotlib import pylab as plt
import pandas as pd
import yfinance as yf

company = "NVDA"
# use multilevel False to avoid double index
df = yf.download(company, start='2026-01-01', end='2026-04-15', multi_level_index=True)

print(df.columns)
# Ensure single-level columns
if isinstance(df.columns, pd.MultiIndex):
    df.columns = df.columns.get_level_values(0)  # Use the first level (e.g., 'NVDA')

print(df.columns)
plt.style.use("default")

plt.figure(f"{company} CandleStick", figsize=(20,10))
plt.title(f"{company} CandleStick")
plt.vlines(x=df.index, ymin=df.Low, ymax=df.High, color="gray")

# Filter for green and red, and drop NaNs
print(df.Open)
green = df.loc[df.Open <= df.Close, ['Open', 'Close', 'High', 'Low']]
green['Height'] = green.Close - green.Open

red = df.loc[df.Open > df.Close, ['Open', 'Close', 'High', 'Low']]
red['Height'] = red.Open - red.Close

# Debug: Check data
print("Green DataFrame:")
print(green[['Open', 'Close', 'Height']].head())
print(green.dtypes)

print("Red DataFrame:")
print(red[['Open', 'Close', 'Height']].head())
print(red.dtypes)

# Plot with NumPy arrays
plt.bar(x=green.index, height=green.Height, bottom=green.Open, color="green")
plt.bar(x=red.index, height=red.Height, bottom=red.Close, color="red")

plt.show()
# Out:
# /tmp/ipykernel_9796/3748244245.py:7: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(company, start='2026-01-01', end='2026-04-15', multi_level_index=True)
# [*********************100%***********************]  1 of 1 completed
# MultiIndex([( 'Close', 'NVDA'),
#             (  'High', 'NVDA'),
#             (   'Low', 'NVDA'),
#             (  'Open', 'NVDA'),
#             ('Volume', 'NVDA')],
#            names=['Price', 'Ticker'])
# Index(['Close', 'High', 'Low', 'Open', 'Volume'], dtype='object', name='Price')
# Date
# 2026-01-02    189.829719
# 2026-01-05    191.749620
# 2026-01-06    190.509695
# 2026-01-07    188.559798
# 2026-01-08    189.099771
#                  ...
# 2026-04-08    184.500000
# 2026-04-09    181.839996
# 2026-04-10    184.309998
# 2026-04-13    186.029999
# 2026-04-14    190.839996
# Name: Open, Length: 70, dtype: float64
# Green DataFrame:
# Price             Open       Close    Height
# Date
# 2026-01-07  188.559798  189.099762  0.539964
# 2026-01-12  183.210085  184.929993  1.719908
# 2026-01-13  184.989988  185.799942  0.809954
# 2026-01-15  186.489913  187.039886  0.549973
# 2026-01-21  179.040316  183.310089  4.269773
# Price
# Open      float64
# Close     float64
# High      float64
# Low       float64
# Height    float64
# dtype: object
# Red DataFrame:
# Price             Open       Close    Height
# Date
# 2026-01-02  189.829719  188.839783  0.989937
# 2026-01-05  191.749620  188.109818  3.639802
# 2026-01-06  190.509695  187.229874  3.279821
# 2026-01-08  189.099771  185.029984  4.069787
# 2026-01-09  185.069980  184.849991  0.219989
# Price
# Open      float64
# Close     float64
# High      float64
# Low       float64
# Height    float64
# dtype: object

# %% [markdown]
# Here are the things we will do in this session:
#
# More pandas!
#
# ![](https://i.natgeofe.com/n/1e38ab75-6d81-45e9-817c-3181a146165e/01pandainsemination_3x2.jpg?w=718&h=479)

# %%
from IPython.display import HTML

# Use the direct URL to the GIF
HTML('<img src="https://media.tenor.com/9icIB76KxhgAAAAC/captain-america-i-can-do-this-all-day.gif" width="800">')
# Out:
# <img src="https://media.tenor.com/9icIB76KxhgAAAAC/captain-america-i-can-do-this-all-day.gif" width="800">

# %%
import pandas as pd

# Load the data
df = pd.read_csv("https://raw.githubusercontent.com/hadley/data-baby-names/master/baby-names.csv")


print(df)
# Filter data according to specific criteria
df_filtered = df[(df.year > 2005) & (df.sex == "boy") & (df.percent > 0.005)]

# Group by 'name' and calculate the mean of the 'percent' column only
grouped = df_filtered.groupby('name')['percent'].mean()
print(grouped)

# Convert the Series back to DataFrame for further manipulation if necessary
mean_df = grouped.reset_index()

# Sort the data by 'percent' in descending order
sorted_mean_df = mean_df.sort_values(by="percent", ascending=False)

# Display the results
print("Final Results")
print(sorted_mean_df.values)
# Out:
#         year      name   percent   sex
# 0       1880      John  0.081541   boy
# 1       1880   William  0.080511   boy
# 2       1880     James  0.050057   boy
# 3       1880   Charles  0.045167   boy
# 4       1880    George  0.043292   boy
# ...      ...       ...       ...   ...
# 257995  2008  Carleigh  0.000128  girl
# 257996  2008     Iyana  0.000128  girl
# 257997  2008    Kenley  0.000127  girl
# 257998  2008    Sloane  0.000127  girl
# 257999  2008   Elianna  0.000127  girl
#
# [258000 rows x 4 columns]
# name
# Aiden          0.006125
# Alexander      0.008361
# Andrew         0.008340
# Angel          0.005220
# Anthony        0.008718
# Benjamin       0.006067
# Brandon        0.005514
# Caleb          0.005012
# Christian      0.006309
# Christopher    0.008788
# Daniel         0.008993
# David          0.007799
# Dylan          0.005728
# Elijah         0.005705
# Ethan          0.009394
# Gabriel        0.005839
# Gavin          0.005391
# Jackson        0.005308
# Jacob          0.010878
# James          0.007183
# Jayden         0.007380
# John           0.006512
# Jonathan       0.006225
# Jose           0.005195
# Joseph         0.007929
# Joshua         0.009427
# Logan          0.006739
# Matthew        0.008595
# Michael        0.009888
# Nathan         0.006248
# Nicholas       0.006461
# Noah           0.007403
# Ryan           0.007119
# Samuel         0.006021
# Tyler          0.006431
# William        0.008535
# Zachary        0.005022
# Name: percent, dtype: float64
# Final Results
# [['Jacob' 0.010877999999999999]
#  ['Michael' 0.009888333333333332]
#  ['Joshua' 0.009426666666666667]
#  ['Ethan' 0.009394]
#  ['Daniel' 0.008993000000000001]
#  ['Christopher' 0.008787999999999999]
#  ['Anthony' 0.008717999999999998]
#  ['Matthew' 0.008595333333333333]
#  ['William' 0.008535]
#  ['Alexander' 0.008361333333333333]
#  ['Andrew' 0.008340333333333333]
#  ['Joseph' 0.007929333333333333]
#  ['David' 0.007799]
#  ['Noah' 0.007403333333333334]
#  ['Jayden' 0.00738]
#  ['James' 0.007183333333333333]
#  ['Ryan' 0.0071193333333333325]
#  ['Logan' 0.006738999999999999]
#  ['John' 0.006512333333333333]
#  ['Nicholas' 0.006461000000000001]
#  ['Tyler' 0.006431333333333333]
#  ['Christian' 0.0063093333333333335]
#  ['Nathan' 0.006247666666666666]
#  ['Jonathan' 0.006225333333333333]
#  ['Aiden' 0.006124666666666667]
#  ['Benjamin' 0.006067333333333333]
#  ['Samuel' 0.006020666666666667]
#  ['Gabriel' 0.005839333333333333]
#  ['Dylan' 0.0057280000000000005]
#  ['Elijah' 0.005704666666666667]
#  ['Brandon' 0.005514333333333334]
#  ['Gavin' 0.0053905]
#  ['Jackson' 0.005308]
#  ['Angel' 0.0052204999999999994]
#  ['Jose' 0.005195]
#  ['Zachary' 0.005022]
#  ['Caleb' 0.005012]]

# %%
import pandas as pd

# Load the data
df = pd.read_csv("https://raw.githubusercontent.com/hadley/data-baby-names/master/baby-names.csv")

# Filter data according to specific criteria
df_filtered = df[(df.year < 1900) & (df.sex == "boy") & (df.percent > 0.005)]

# Group by 'name' and calculate the mean of the 'percent' column only
grouped = df_filtered.groupby('name')['percent'].mean()

# Convert the Series back to DataFrame for further manipulation if necessary
mean_df = grouped.reset_index()

# Sort the data by 'percent' in descending order
sorted_mean_df = mean_df.sort_values(by="percent", ascending=False)

# Display the results
print(sorted_mean_df.values)
# Out:
# [['John' 0.07102610000000001]
#  ['William' 0.06543695000000001]
#  ['James' 0.043582749999999996]
#  ['George' 0.03786875]
#  ['Charles' 0.03483315]
#  ['Frank' 0.024822749999999998]
#  ['Joseph' 0.022939300000000003]
#  ['Robert' 0.0208347]
#  ['Henry' 0.0190637]
#  ['Edward' 0.01877475]
#  ['Thomas' 0.0186726]
#  ['Harry' 0.0182779]
#  ['Walter' 0.01563325]
#  ['Arthur' 0.013516549999999999]
#  ['Fred' 0.012426650000000001]
#  ['Albert' 0.0116921]
#  ['Clarence' 0.0085437]
#  ['Dewey' 0.008439]
#  ['Roy' 0.00737525]
#  ['Willie' 0.0071966]
#  ['Samuel' 0.0070788000000000005]
#  ['Louis' 0.006948650000000001]
#  ['Harold' 0.006737]
#  ['Paul' 0.0066235]
#  ['Grover' 0.006579]
#  ['Earl' 0.006524583333333334]
#  ['Raymond' 0.006317111111111111]
#  ['Carl' 0.006290615384615385]
#  ['Benjamin' 0.006198]
#  ['David' 0.0061966]
#  ['Joe' 0.0060475500000000005]
#  ['Richard' 0.0060464]
#  ['Ernest' 0.0060462]
#  ['Charlie' 0.00596555]
#  ['Ralph' 0.005722777777777778]
#  ['Jesse' 0.0053428]
#  ['Daniel' 0.005330666666666667]
#  ['Andrew' 0.00528525]
#  ['Will' 0.0052731]
#  ['Herbert' 0.00527]
#  ['Oscar' 0.005232125]
#  ['Howard' 0.0051924]
#  ['Jack' 0.005052]]

# %% [markdown]
# # Covid Time
# <img src="https://www.un.org/sites/un2.un.org/files/field/image/coronavirus.jpg">

# %% [markdown]
# # 🦠 COVID-19 Data Analysis with Pandas
#
# ## What we'll learn in this notebook:
# 1. How to **fetch live data** from a government API (CDC)
# 2. How to **clean and transform** real-world data with Pandas
# 3. How to **visualize trends** using Matplotlib
# 4. How to work with **time series** data
#
# ---
#
# ### ⚠️ Background: The CDC changed their data source!
#
# The old way to get COVID data used to be:
# ```python
# # ❌ THIS NO LONGER WORKS (returns 404 error)
# df = pd.read_json("https://covid.cdc.gov/covid-data-tracker/COVIDData/getAjaxData?id=us_trend_by_USA_v2")
# ```
#
# The CDC retired the old COVID Data Tracker API. The data now lives on **data.cdc.gov** using the **Socrata Open Data API (SODA)**.
#
# The dataset we'll use: **[Provisional COVID-19 Death Counts by Week Ending Date and State](https://data.cdc.gov/d/r8kw-7aab)**
# Source: National Center for Health Statistics (NCHS)

# %% [markdown]
# ---
# ## Step 1: Imports
#
# We only need three libraries — all pre-installed in Google Colab.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

print(f"Pandas version: {pd.__version__}")
print("Ready to go! ✅")
# Out:
# Pandas version: 2.2.2
# Ready to go! ✅

# %% [markdown]
# ---
# ## Step 2: Fetch COVID-19 Data from the CDC API
#
# The new CDC data lives on `data.cdc.gov` and uses the **Socrata API**.
#
# **Key things about the API URL:**
# - `r8kw-7aab` is the **dataset ID** (like a unique code for this specific dataset)
# - `$where` filters the data (we want US national totals, grouped by week)
# - `$order` sorts chronologically
# - `$limit` controls how many rows we get (50000 is more than enough)
# - `` `group` `` needs backticks because "group" is a reserved word in SoQL
#
# 💡 **SoQL** = Socrata Query Language (similar to SQL)

# %%
# Build the API URL
BASE_URL = "https://data.cdc.gov/resource/r8kw-7aab.json"

params = {
    "$where":  "state='United States' AND `group`='By Week'",
    "$order":  "end_date ASC",
    "$limit":  "50000"
}

# Pandas can read JSON directly from a URL!
from urllib.parse import urlencode
url = f"{BASE_URL}?{urlencode(params)}"
print("Fetching data from:")
print(url)
print("\nPlease wait...")

df = pd.read_json(url)
print(f"\n✅ Downloaded {len(df)} rows of data!")
df.head()
# Out:
# Fetching data from:
# https://data.cdc.gov/resource/r8kw-7aab.json?%24where=state%3D%27United+States%27+AND+%60group%60%3D%27By+Week%27&%24order=end_date+ASC&%24limit=50000
#
# Please wait...
#
# ✅ Downloaded 327 rows of data!
#                 data_as_of               start_date                 end_date  \
# 0  2026-04-09T00:00:00.000  2019-12-29T00:00:00.000  2020-01-04T00:00:00.000
# 1  2026-04-09T00:00:00.000  2020-01-05T00:00:00.000  2020-01-11T00:00:00.000
# 2  2026-04-09T00:00:00.000  2020-01-12T00:00:00.000  2020-01-18T00:00:00.000
# 3  2026-04-09T00:00:00.000  2020-01-19T00:00:00.000  2020-01-25T00:00:00.000
# 4  2026-04-09T00:00:00.000  2020-01-26T00:00:00.000  2020-02-01T00:00:00.000
#
#      group       year  mmwr_week         week_ending_date          state  \
# 0  By Week  2019/2020          1  2020-01-04T00:00:00.000  United States
# 1  By Week       2020          2  2020-01-11T00:00:00.000  United States
# 2  By Week       2020          3  2020-01-18T00:00:00.000  United States
# 3  By Week       2020          4  2020-01-25T00:00:00.000  United States
# 4  By Week       2020          5  2020-02-01T00:00:00.000  United States
#
#    covid_19_deaths  total_deaths  percent_of_expected_deaths  \
# 0                0         60170                          98
# 1                1         60734                          97
# 2                2         59362                          98
# 3                3         59162                          99
# 4                0         58834                          99
#
#    pneumonia_deaths  pneumonia_and_covid_19_deaths  influenza_deaths  \
# 0              4111                              0               434
# 1              4153                              1               475
# 2              4066                              2               468
# 3              3915                              0               500
# 4              3818                              0               481
#
#    pneumonia_influenza_or_covid_19_deaths
# 0                                    4545
# 1                                    4628
# 2                                    4534
# 3                                    4418
# 4                                    4299

# %% [markdown]
# ---
# ## Step 3: Explore the raw data
#
# Before doing anything, let's understand what we have.

# %%
# What columns do we have?
print("Columns:")
print(df.columns.tolist())
print(f"\nShape: {df.shape[0]} rows x {df.shape[1]} columns")
print(f"\nData types:")
print(df.dtypes)
# Out:
# Columns:
# ['data_as_of', 'start_date', 'end_date', 'group', 'year', 'mmwr_week', 'week_ending_date', 'state', 'covid_19_deaths', 'total_deaths', 'percent_of_expected_deaths', 'pneumonia_deaths', 'pneumonia_and_covid_19_deaths', 'influenza_deaths', 'pneumonia_influenza_or_covid_19_deaths']
#
# Shape: 327 rows x 15 columns
#
# Data types:
# data_as_of                                object
# start_date                                object
# end_date                                  object
# group                                     object
# year                                      object
# mmwr_week                                  int64
# week_ending_date                          object
# state                                     object
# covid_19_deaths                            int64
# total_deaths                               int64
# percent_of_expected_deaths                 int64
# pneumonia_deaths                           int64
# pneumonia_and_covid_19_deaths              int64
# influenza_deaths                           int64
# pneumonia_influenza_or_covid_19_deaths     int64
# dtype: object

# %%
# Let's look at the first and last few rows
print("=== First 3 rows ===")
print(df.head(3))
print("\n=== Last 3 rows ===")
print(df.tail(3))
# Out:
# === First 3 rows ===
#                 data_as_of               start_date                 end_date  \
# 0  2026-04-09T00:00:00.000  2019-12-29T00:00:00.000  2020-01-04T00:00:00.000
# 1  2026-04-09T00:00:00.000  2020-01-05T00:00:00.000  2020-01-11T00:00:00.000
# 2  2026-04-09T00:00:00.000  2020-01-12T00:00:00.000  2020-01-18T00:00:00.000
#
#      group       year  mmwr_week         week_ending_date          state  \
# 0  By Week  2019/2020          1  2020-01-04T00:00:00.000  United States
# 1  By Week       2020          2  2020-01-11T00:00:00.000  United States
# 2  By Week       2020          3  2020-01-18T00:00:00.000  United States
#
#    covid_19_deaths  total_deaths  percent_of_expected_deaths  \
# 0                0         60170                          98
# 1                1         60734                          97
# 2                2         59362                          98
#
#    pneumonia_deaths  pneumonia_and_covid_19_deaths  influenza_deaths  \
# 0              4111                              0               434
# 1              4153                              1               475
# 2              4066                              2               468
#
#    pneumonia_influenza_or_covid_19_deaths
# 0                                    4545
# 1                                    4628
# 2                                    4534
#
# === Last 3 rows ===
#                   data_as_of               start_date  \
# 324  2026-04-09T00:00:00.000  2026-03-15T00:00:00.000
# 325  2026-04-09T00:00:00.000  2026-03-22T00:00:00.000
# 326  2026-04-09T00:00:00.000  2026-03-29T00:00:00.000
#
#                     end_date    group  year  mmwr_week  \
# 324  2026-03-21T00:00:00.000  By Week  2026         11
# 325  2026-03-28T00:00:00.000  By Week  2026         12
# 326  2026-04-04T00:00:00.000  By Week  2026         13
#
#             week_ending_date          state  covid_19_deaths  total_deaths  \
# 324  2026-03-21T00:00:00.000  United States              172         49650
# 325  2026-03-28T00:00:00.000  United States              125         38932
# 326  2026-04-04T00:00:00.000  United States               78         23243
#
#      percent_of_expected_deaths  pneumonia_deaths  \
# 324                          87              2819
# 325                          69              2225
# 326                          42              1211
#
#      pneumonia_and_covid_19_deaths  influenza_deaths  \
# 324                             84               160
# 325                             53               108
# 326                             35                59
#
#      pneumonia_influenza_or_covid_19_deaths
# 324                                    3063
# 325                                    2403
# 326                                    1313

# %% [markdown]
# ---
# ## Step 4: Clean and prepare the data
#
# We need to:
# 1. Keep only the columns we care about
# 2. Set `week_ending_date` as our index
# 3. Make sure dates are proper `datetime` objects
# 4. Make sure numeric columns are actually numbers

# %%
# Select only the columns we need
columns_to_keep = [
    'week_ending_date',
    'covid_19_deaths',
    'total_deaths',
    'pneumonia_deaths',
    'influenza_deaths',
    'pneumonia_and_covid_19_deaths'
]

# Only keep columns that exist (some might be missing)
columns_to_keep = [c for c in columns_to_keep if c in df.columns]
df2 = df[columns_to_keep].copy()

print(f"Kept {len(columns_to_keep)} columns:")
print(columns_to_keep)
df2
# Out:
# Kept 6 columns:
# ['week_ending_date', 'covid_19_deaths', 'total_deaths', 'pneumonia_deaths', 'influenza_deaths', 'pneumonia_and_covid_19_deaths']
#             week_ending_date  covid_19_deaths  total_deaths  pneumonia_deaths  \
# 0    2020-01-04T00:00:00.000                0         60170              4111
# 1    2020-01-11T00:00:00.000                1         60734              4153
# 2    2020-01-18T00:00:00.000                2         59362              4066
# 3    2020-01-25T00:00:00.000                3         59162              3915
# 4    2020-02-01T00:00:00.000                0         58834              3818
# ..                       ...              ...           ...               ...
# 322  2026-03-07T00:00:00.000              283         57934              3377
# 323  2026-03-14T00:00:00.000              215         54869              3085
# 324  2026-03-21T00:00:00.000              172         49650              2819
# 325  2026-03-28T00:00:00.000              125         38932              2225
# 326  2026-04-04T00:00:00.000               78         23243              1211
#
#      influenza_deaths  pneumonia_and_covid_19_deaths
# 0                 434                              0
# 1                 475                              1
# 2                 468                              2
# 3                 500                              0
# 4                 481                              0
# ..                ...                            ...
# 322               332                            121
# 323               250                             78
# 324               160                             84
# 325               108                             53
# 326                59                             35
#
# [327 rows x 6 columns]

# %%
# Convert week_ending_date to datetime and set as index
df2['week_ending_date'] = pd.to_datetime(df2['week_ending_date'])
df3 = df2.set_index('week_ending_date')

# Make sure all numeric columns are actually numeric
for col in df3.columns:
    df3[col] = pd.to_numeric(df3[col], errors='coerce')

print("Index type:", type(df3.index))
print("\nData types after cleaning:")
print(df3.dtypes)
print(f"\nDate range: {df3.index.min()} to {df3.index.max()}")
df3.head()
# Out:
# Index type: <class 'pandas.core.indexes.datetimes.DatetimeIndex'>
#
# Data types after cleaning:
# covid_19_deaths                  int64
# total_deaths                     int64
# pneumonia_deaths                 int64
# influenza_deaths                 int64
# pneumonia_and_covid_19_deaths    int64
# dtype: object
#
# Date range: 2020-01-04 00:00:00 to 2026-04-04 00:00:00
#                   covid_19_deaths  total_deaths  pneumonia_deaths  \
# week_ending_date
# 2020-01-04                      0         60170              4111
# 2020-01-11                      1         60734              4153
# 2020-01-18                      2         59362              4066
# 2020-01-25                      3         59162              3915
# 2020-02-01                      0         58834              3818
#
#                   influenza_deaths  pneumonia_and_covid_19_deaths
# week_ending_date
# 2020-01-04                     434                              0
# 2020-01-11                     475                              1
# 2020-01-18                     468                              2
# 2020-01-25                     500                              0
# 2020-02-01                     481                              0

# %%
# Let's check the index
print("Index:")
print(df3.index)
print(f"\nTotal weeks of data: {len(df3)}")
# Out:
# Index:
# DatetimeIndex(['2020-01-04', '2020-01-11', '2020-01-18', '2020-01-25',
#                '2020-02-01', '2020-02-08', '2020-02-15', '2020-02-22',
#                '2020-02-29', '2020-03-07',
#                ...
#                '2026-01-31', '2026-02-07', '2026-02-14', '2026-02-21',
#                '2026-02-28', '2026-03-07', '2026-03-14', '2026-03-21',
#                '2026-03-28', '2026-04-04'],
#               dtype='datetime64[ns]', name='week_ending_date', length=327, freq=None)
#
# Total weeks of data: 327

# %% [markdown]
# ---
# ## Step 5: Add a cumulative deaths column
#
# The old CDC API had a `COVID_deaths_total` column (cumulative).
# The new API only gives us **weekly** counts, so we compute the cumulative sum ourselves using `.cumsum()`.

# %%
# Create cumulative (running total) column
df3['covid_deaths_cumulative'] = df3['covid_19_deaths'].cumsum()

print(f"Total cumulative COVID-19 deaths: {df3['covid_deaths_cumulative'].iloc[-1]:,.0f}")
print(f"Peak weekly deaths: {df3['covid_19_deaths'].max():,.0f} (week of {df3['covid_19_deaths'].idxmax().date()})")
df3[['covid_19_deaths', 'covid_deaths_cumulative']].tail(10)
# Out:
# Total cumulative COVID-19 deaths: 1,244,663
# Peak weekly deaths: 26,028 (week of 2021-01-09)
#                   covid_19_deaths  covid_deaths_cumulative
# week_ending_date
# 2026-01-31                    406                  1242408
# 2026-02-07                    405                  1242813
# 2026-02-14                    331                  1243144
# 2026-02-21                    340                  1243484
# 2026-02-28                    306                  1243790
# 2026-03-07                    283                  1244073
# 2026-03-14                    215                  1244288
# 2026-03-21                    172                  1244460
# 2026-03-28                    125                  1244585
# 2026-04-04                     78                  1244663

# %% [markdown]
# ---
# ## Step 6: Quick stats with `.describe()`
#
# Pandas gives us summary statistics for free.

# %%
df3.describe()
# Out:
#        covid_19_deaths  total_deaths  pneumonia_deaths  influenza_deaths  \
# count       327.000000    327.000000        327.000000        327.000000
# mean       3806.308869  61831.565749       4998.152905        187.559633
# std        5335.894733   7106.084142       2883.531077        322.767588
# min           0.000000  23243.000000       1211.000000          3.000000
# 25%         508.500000  57431.000000       3309.500000         20.500000
# 50%        1549.000000  59682.000000       3833.000000         41.000000
# 75%        4292.500000  64271.000000       5069.500000        162.500000
# max       26028.000000  87415.000000      16923.000000       1882.000000
#
#        pneumonia_and_covid_19_deaths  covid_deaths_cumulative
# count                     327.000000             3.270000e+02
# mean                     1857.183486             9.076258e+05
# std                      2823.511953             3.980280e+05
# min                         0.000000             0.000000e+00
# 25%                       203.000000             6.140570e+05
# 50%                       561.000000             1.116994e+06
# 75%                      2145.500000             1.208390e+06
# max                     13560.000000             1.244663e+06

# %% [markdown]
# ---
# ## 📊 Step 7: Visualizations
#
# Now the fun part — let's plot the data!

# %% [markdown]
# ### Plot 1: Cumulative COVID-19 Deaths (line chart)
#
# This is equivalent to the old `df3['COVID_deaths_total'].plot()` from the previous notebook.

# %%
plt.ticklabel_format(style='plain')
df3['covid_deaths_cumulative'].plot(
    figsize=(30, 15),
    color='darkred',
    linewidth=2,
    title='Cumulative COVID-19 Deaths in the United States'
)
plt.ylabel('Cumulative Deaths')
plt.xlabel('Week Ending Date')
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# ### Plot 2: Weekly COVID-19 Deaths (bar chart)
#
# This is equivalent to the old `df3['COVID_deaths_weekly'].plot(kind='bar')` from the previous notebook.

# %%
plt.ticklabel_format(style='plain')
df3['covid_19_deaths'].plot(
    figsize=(25, 10),
    kind='bar',
    color='crimson',
    title='Weekly COVID-19 Deaths in the United States'
)
plt.ylabel('Weekly Deaths')
plt.xlabel('Week Ending Date')
plt.show()

# %% [markdown]
# ### Plot 3: Weekly Deaths as an area chart (cleaner look)
#
# The bar chart with 300+ weeks is hard to read. An **area chart** works better for this much data.

# %%
fig, ax = plt.subplots(figsize=(25, 10))
ax.fill_between(df3.index, df3['covid_19_deaths'], alpha=0.3, color='crimson')
ax.plot(df3.index, df3['covid_19_deaths'], linewidth=1.5, color='crimson')
ax.set_title('Weekly COVID-19 Deaths in the United States', fontsize=20, fontweight='bold')
ax.set_xlabel('Date', fontsize=14)
ax.set_ylabel('Weekly Deaths', fontsize=14)
ax.ticklabel_format(style='plain', axis='y')
ax.xaxis.set_major_locator(mdates.MonthLocator(interval=3))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
plt.xticks(rotation=45, ha='right')
ax.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## 📊 Step 8: Compare COVID, Pneumonia, and Influenza Deaths
#
# The new dataset includes **pneumonia** and **influenza** death counts — something the old API didn't expose as easily. Let's compare them!

# %%
# Compare the three causes of death
compare_cols = ['covid_19_deaths', 'pneumonia_deaths', 'influenza_deaths']
# Only use columns that exist
compare_cols = [c for c in compare_cols if c in df3.columns]

df3[compare_cols].plot(
    figsize=(25, 10),
    linewidth=1.5,
    title='Weekly Deaths: COVID-19 vs Pneumonia vs Influenza'
)
plt.ylabel('Weekly Deaths')
ax.ticklabel_format(style='plain', axis='y')
plt.grid(True, alpha=0.3)
plt.legend(fontsize=12)
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## Step 9: Zoom into a specific time period
#
# With time-series indexed DataFrames, you can **slice by date strings** — one of Pandas' superpowers!

# %%
# Last 52 weeks (approximately 1 year)
last_year = df3.iloc[-52:]

print(f"Showing data from {last_year.index[0].date()} to {last_year.index[-1].date()}")

last_year[['covid_19_deaths', 'influenza_deaths']].plot(
    figsize=(20, 10),
    kind='bar',
    title='Last 52 Weeks: COVID-19 vs Influenza Deaths'
)
plt.ylabel('Weekly Deaths')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# Showing data from 2025-04-12 to 2026-03-28

# %%
# You can also slice by date string!
# Example: just the Delta wave (Aug-Nov 2021)
delta_wave = df3.loc['2021-07':'2021-12']

delta_wave['covid_19_deaths'].plot(
    figsize=(15, 7),
    kind='bar',
    color='darkorange',
    title='Delta Wave: Weekly COVID-19 Deaths (Jul-Dec 2021)'
)
plt.ylabel('Weekly Deaths')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## Step 10: COVID deaths as a percentage of all deaths
#
# We can create new columns by doing math on existing ones.

# %%
# Calculate what % of all deaths each week were due to COVID
df3['covid_pct_of_total'] = (df3['covid_19_deaths'] / df3['total_deaths']) * 100

fig, ax = plt.subplots(figsize=(25, 10))
ax.fill_between(df3.index, df3['covid_pct_of_total'], alpha=0.4, color='steelblue')
ax.plot(df3.index, df3['covid_pct_of_total'], color='steelblue', linewidth=1.5)
ax.set_title('COVID-19 Deaths as % of All U.S. Deaths', fontsize=20, fontweight='bold')
ax.set_ylabel('% of All Deaths', fontsize=14)
ax.set_xlabel('Date', fontsize=14)
ax.xaxis.set_major_locator(mdates.MonthLocator(interval=3))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
plt.xticks(rotation=45, ha='right')
ax.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

print(f"\nPeak: {df3['covid_pct_of_total'].max():.1f}% of all deaths were COVID (week of {df3['covid_pct_of_total'].idxmax().date()})")
print(f"Most recent week: {df3['covid_pct_of_total'].iloc[-1]:.1f}%")
# Out:
# Peak: 29.9% of all deaths were COVID (week of 2021-01-09)
# Most recent week: 0.3%

# %% [markdown]
# ---
# ## Step 11: Subplots — multiple charts in one figure

# %%
fig, axes = plt.subplots(2, 2, figsize=(24, 14))
fig.suptitle('COVID-19 Dashboard — United States', fontsize=22, fontweight='bold', y=1.02)

# Top-left: Cumulative deaths
df3['covid_deaths_cumulative'].plot(ax=axes[0, 0], color='darkred', linewidth=2)
axes[0, 0].set_title('Cumulative COVID-19 Deaths')
axes[0, 0].ticklabel_format(style='plain', axis='y')
axes[0, 0].grid(True, alpha=0.3)

# Top-right: Weekly deaths
df3['covid_19_deaths'].plot(ax=axes[0, 1], color='crimson', linewidth=1.5)
axes[0, 1].set_title('Weekly COVID-19 Deaths')
axes[0, 1].ticklabel_format(style='plain', axis='y')
axes[0, 1].grid(True, alpha=0.3)

# Bottom-left: COVID as % of total deaths
df3['covid_pct_of_total'].plot(ax=axes[1, 0], color='steelblue', linewidth=1.5)
axes[1, 0].set_title('COVID-19 as % of All Deaths')
axes[1, 0].set_ylabel('%')
axes[1, 0].grid(True, alpha=0.3)

# Bottom-right: Total deaths (all causes)
df3['total_deaths'].plot(ax=axes[1, 1], color='gray', linewidth=1.5)
axes[1, 1].set_title('Total Weekly Deaths (All Causes)')
axes[1, 1].ticklabel_format(style='plain', axis='y')
axes[1, 1].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## 🧪 Step 12: Bonus — Get data by State
#
# The same API lets you filter by **state**. Let's compare a few states.

# %%
def get_state_data(state_name):
    """Fetch weekly COVID death data for a specific state."""
    params = {
        "$where":  f"state='{state_name}' AND `group`='By Week'",
        "$order":  "end_date ASC",
        "$limit":  "50000",
        "$select": "week_ending_date,covid_19_deaths,total_deaths"
    }
    url = f"{BASE_URL}?{urlencode(params)}"
    state_df = pd.read_json(url)
    state_df['week_ending_date'] = pd.to_datetime(state_df['week_ending_date'])
    state_df = state_df.set_index('week_ending_date')
    state_df['covid_19_deaths'] = pd.to_numeric(state_df['covid_19_deaths'], errors='coerce')
    return state_df

# Fetch data for a few states
states = ['California', 'Texas', 'New York', 'Florida']
state_data = {}

for state in states:
    print(f"Fetching {state}...")
    state_data[state] = get_state_data(state)

print("\nDone! ✅")
# Out:
# Fetching California...
# Fetching Texas...
# Fetching New York...
# Fetching Florida...
#
# Done! ✅

# %%
# Plot all states on the same chart
fig, ax = plt.subplots(figsize=(25, 10))

for state_name, state_df in state_data.items():
    ax.plot(state_df.index, state_df['covid_19_deaths'], linewidth=1.5, label=state_name)

ax.set_title('Weekly COVID-19 Deaths by State', fontsize=20, fontweight='bold')
ax.set_ylabel('Weekly Deaths', fontsize=14)
ax.set_xlabel('Date', fontsize=14)
ax.legend(fontsize=14)
ax.ticklabel_format(style='plain', axis='y')
ax.xaxis.set_major_locator(mdates.MonthLocator(interval=3))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
plt.xticks(rotation=45, ha='right')
ax.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %%
import numpy as np
df1 = pd.DataFrame() # empty data frame
s1 = np.arange(0, 1000)
# s2 = np.sin(s1)
s2 = np.sin(s1/50)

df1.index = s1
df1['sin'] = s2

df1.plot()
# Out:
# <Axes: >

# %%
df2 = df1.copy()
df2[df2['sin'] > 0.5] = 0.3
df2[df2['sin'] < -0.5] = -0.8

df2.plot()
# Out:
# <Axes: >

# %%
s3 = pd.Series(np.random.randn(1000)/10)
s4 = s3.cumsum()
s4
# Out:
# 0     -0.090429
# 1      0.066122
# 2      0.285662
# 3      0.571391
# 4      0.304049
#          ...
# 995    0.875920
# 996    1.053946
# 997    1.129163
# 998    1.024374
# 999    0.868326
# Length: 1000, dtype: float64

# %%
df2['random'] = s4
df2.plot(figsize=(20, 10))
# Out:
# <Axes: >

# %% [markdown]
# #<Center> Homework
# <img src=http://2.bp.blogspot.com/-KJonHReE80I/VDwLlsZXgEI/AAAAAAAAMcc/_nhlmp4Jk5g/s1600/Do%2Byou%2Bwant%2Bme%2Bto%2Beat%2Bit.jpg >
#
# - Download data for 2-3 companies that are related. For example: Nike and Adidas, Honda and Toyota, etc
# - Plot their stock graph on the same figure over the same period of time
# - Do you observe any correlation?
# - You can use yahoo finance to get the data in .csv format <br>
# https://finance.yahoo.com/quote/NKE/history?p=NKE
# - Or you can use the above example

# %%
from matplotlib import pylab as plt
import pandas as pd
import yfinance as yf

company = "NVDA"
df = yf.download(company, start='2025-01-01', end='2025-04-24')
print(df.columns)
# Ensure single-level columns
if isinstance(df.columns, pd.MultiIndex):
    df.columns = df.columns.get_level_values(0)  # Use the first level (e.g., 'NVDA')

df[["Close", "Open"]].plot(figsize=(20, 10))

# %%
df[['Open', 'High', 'Low', 'Close']].plot(subplots=True, figsize=(20, 15), layout=(2, 2), sharex=True)
plt.suptitle("NVDA Stock Prices (Excluding Volume)", y=1.02)
plt.tight_layout()
plt.show()

# %%
from matplotlib import pylab as plt
import pandas as pd
import yfinance as yf

# 3 healthcare/medtech companies
companies = ["HO1.HA", "SYK", "JNJ"]

df = yf.download(companies, start='2020-01-01', end='2025-04-24')
print(df.columns)

if isinstance(df.columns, pd.MultiIndex):
    df.columns = df.columns.get_level_values(0)  # Use the first level (e.g., 'NVDA')

close_prices = df["Close"]
close_prices.plot(figsize=(20,10))
plt.title("Hologic, Stryker & JNJ - Closing Prices")
plt.show()
# Out:
# /tmp/ipykernel_9513/1695016002.py:8: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(companies, start='2020-01-01', end='2025-04-24')
# [*********************100%***********************]  3 of 3 completed
# MultiIndex([( 'Close', 'HO1.HA'),
#             ( 'Close',    'JNJ'),
#             ( 'Close',    'SYK'),
#             (  'High', 'HO1.HA'),
#             (  'High',    'JNJ'),
#             (  'High',    'SYK'),
#             (   'Low', 'HO1.HA'),
#             (   'Low',    'JNJ'),
#             (   'Low',    'SYK'),
#             (  'Open', 'HO1.HA'),
#             (  'Open',    'JNJ'),
#             (  'Open',    'SYK'),
#             ('Volume', 'HO1.HA'),
#             ('Volume',    'JNJ'),
#             ('Volume',    'SYK')],
#            names=['Price', 'Ticker'])
